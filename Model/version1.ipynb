# %%
# import required libraries
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

# %%
# read data
train = pd.read_csv("../data_set/train.csv")
test = pd.read_csv("../data_set/test.csv")
store = pd.read_csv("../data_set/store.csv")

# %%
#train
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# check nan (train)
display(train.isnull().sum())
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
train['Date'] = pd.to_datetime(train['Date'], errors='coerce')

# %%
summary = pd.DataFrame({
    'Column': train.columns,
    'Unique Values': [train[col].nunique() for col in train.columns],
    'Min': [train[col].min() if np.issubdtype(train[col].dtype, np.number) or np.issubdtype(train[col].dtype, np.datetime64) else None for col in train.columns],
    'Max': [train[col].max() if np.issubdtype(train[col].dtype, np.number) or np.issubdtype(train[col].dtype, np.datetime64) else None for col in train.columns],
})

summary.set_index('Column')
# Out:
#                Unique Values                  Min                  Max
# Column
# Store                   1115                    1                 1115
# DayOfWeek                  7                    1                    7
# Date                     942  2013-01-01 00:00:00  2015-07-31 00:00:00
# Sales                  21734                    0                41551
# Customers               4086                    0                 7388
# Open                       2                    0                    1
# Promo                      2                    0                    1
# StateHoliday               5                 None                 None
# SchoolHoliday              2                    0                    1

# %%
plt.figure(figsize=(10, 6))
sns.histplot(train['Sales'], kde=True, color='red', bins=50)
plt.title('Univariate Analysis: Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
train = train[train["Sales"] > 0]

# %% [markdown]
# ## In the training data, we remove rows where sales are equal to zero:
#
#
# ### ✅ Why Remove Rows Where `Sales == 0`
#
# - **Store Closed:**
#   Most instances with `Sales = 0` correspond to days when the store was closed. Including them may distort the model by teaching it to predict zeros where it shouldn't.
#
# - **Focus on Business Days:**
#   Our goal is to predict sales on days when stores are open. Modeling closed-store behavior (zero sales) is not informative for actual forecasting.
#
# - **Noise Reduction:**
#   Including many zero-sale days can introduce noise and skew the learning process, especially for models sensitive to outliers or class imbalance.
#
# > ⚠️ **Note:** If our objective were to predict whether a store is open or closed, we would keep these rows. But since we're forecasting real sales amounts, it's best to remove them.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(train['Sales'], kde=True, color='red', bins=50)
plt.title('Univariate Analysis: Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting the range of dates
plt.figure(figsize=(8, 5))
plt.plot(train['Date'], [1] * len(train['Date']), marker='o', linestyle='')

# Formatting the x-axis to show dates in yyyy-mm-dd format
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Adding title and labels
plt.title('Range of Dates')
plt.xlabel('Date')
plt.ylabel('')

# Show the plot
plt.tight_layout()
plt.show()

# %%
train.sort_values(by = 'Date', ascending=False, inplace=True)

# Print the maximum and minimum dates
max_date = train['Date'].max()
min_date = train['Date'].min()

print("\nMinimum Date:", min_date)
print("Maximum Date:", max_date)
# Out:
# Minimum Date: 2013-01-01 00:00:00
# Maximum Date: 2015-07-31 00:00:00

# %%
# Bivariate Analysis: Sales vs. Promotion
plt.figure(figsize=(10, 6))
sns.boxplot(x='Promo', y='Sales', data = train, palette='coolwarm')
plt.title('Bivariate Analysis: Sales vs. Promotion')
plt.xlabel('Promo (0=No, 1=Yes)')
plt.ylabel('Sales')
plt.show()

# %%
sns.barplot(data = train, x = 'StateHoliday', y = 'Sales')
# Out:
# <Axes: xlabel='StateHoliday', ylabel='Sales'>

# %%
sns.barplot(x = train.DayOfWeek, y = train.Sales)
# Out:
# <Axes: xlabel='DayOfWeek', ylabel='Sales'>

# %%
plt.figure(figsize=(20, 10))
# Sales vs Customers Scatter Plot
sns.scatterplot(x = train.Sales, y = train.Customers)
plt.title("Sales vs Customers")
# Out:
# Text(0.5, 1.0, 'Sales vs Customers')

# %%
#test
test.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
# check nan (test)
display(test.isnull().sum())
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %% [markdown]
# ### As the store is expected to be open in the test dataset, we replace missing values in the `Open` column with `1`.

# %%
test.fillna(1, inplace = True)

# %%
test[test['Open'].isnull()]
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 479      480    622          4  2015-09-17   NaN      1            0
# 1335    1336    622          3  2015-09-16   NaN      1            0
# 2191    2192    622          2  2015-09-15   NaN      1            0
# 3047    3048    622          1  2015-09-14   NaN      1            0
# 4759    4760    622          6  2015-09-12   NaN      0            0
# 5615    5616    622          5  2015-09-11   NaN      0            0
# 6471    6472    622          4  2015-09-10   NaN      0            0
# 7327    7328    622          3  2015-09-09   NaN      0            0
# 8183    8184    622          2  2015-09-08   NaN      0            0
# 9039    9040    622          1  2015-09-07   NaN      0            0
# 10751  10752    622          6  2015-09-05   NaN      0            0
#
#        SchoolHoliday
# 479                0
# 1335               0
# 2191               0
# 3047               0
# 4759               0
# 5615               0
# 6471               0
# 7327               0
# 8183               0
# 9039               0
# 10751              0

# %%
# check nan (test)
display(test.isnull().sum())
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
test['Date'] = pd.to_datetime(test['Date'])
test['DayOfWeek'] = test['Date'].dt.dayofweek
test['Month'] = test['Date'].dt.month

# %%
summary = pd.DataFrame({
    'Column': test.columns,
    'Unique Values': [test[col].nunique() for col in test.columns],
    'Min': [test[col].min() if np.issubdtype(test[col].dtype, np.number) or np.issubdtype(test[col].dtype, np.datetime64) else None for col in test.columns],
    'Max': [test[col].max() if np.issubdtype(test[col].dtype, np.number) or np.issubdtype(test[col].dtype, np.datetime64) else None for col in test.columns],
})

summary.set_index('Column')
# Out:
#                Unique Values                  Min                  Max
# Column
# Id                     41088                    1                41088
# Store                    856                    1                 1115
# DayOfWeek                  7                    0                    6
# Date                      48  2015-08-01 00:00:00  2015-09-17 00:00:00
# Open                       2                  0.0                  1.0
# Promo                      2                    0                    1
# StateHoliday               2                 None                 None
# SchoolHoliday              2                    0                    1
# Month                      2                    8                    9

# %%
#store
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
# check nan (store)
display(store.isnull().sum())
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store.fillna(0, inplace = True)

# %%
# check nan (store)
display(store.isnull().sum())
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
summary = pd.DataFrame({
    'Column': store.columns,
    'Unique Values': [store[col].nunique() for col in store.columns],
    'Min': [store[col].min() if np.issubdtype(store[col].dtype, np.number) or np.issubdtype(store[col].dtype, np.datetime64) else None for col in store.columns],
    'Max': [store[col].max() if np.issubdtype(store[col].dtype, np.number) or np.issubdtype(store[col].dtype, np.datetime64) else None for col in store.columns],
})

summary.set_index('Column')
# Out:
#                            Unique Values  Min      Max
# Column
# Store                               1115  1.0   1115.0
# StoreType                              4  NaN      NaN
# Assortment                             3  NaN      NaN
# CompetitionDistance                  655  0.0  75860.0
# CompetitionOpenSinceMonth             13  0.0     12.0
# CompetitionOpenSinceYear              24  0.0   2015.0
# Promo2                                 2  0.0      1.0
# Promo2SinceWeek                       25  0.0     50.0
# Promo2SinceYear                        8  0.0   2015.0
# PromoInterval                          4  NaN      NaN

# %%
train = train.merge(store, on='Store', how='left')
test = test.merge(store, on='Store', how='left')

# %%
train.StateHoliday.value_counts()
# Out:
# StateHoliday
# 0    855087
# 0    131072
# a     20260
# b      6690
# c      4100
# Name: count, dtype: int64

# %%
# Replacing string '0' as integer '0'

train['StateHoliday'] = train['StateHoliday'].replace({'0': 0})
test['StateHoliday'] = test['StateHoliday'].replace({'0': 0})

train.StateHoliday.value_counts()
# Out:
# StateHoliday
# 0    986159
# a     20260
# b      6690
# c      4100
# Name: count, dtype: int64

# %%
# Visualizing sales for each month over time

# Convert 'Date' column to datetime format
tmp_train = train.copy()
tmp_train['Date'] = pd.to_datetime(tmp_train['Date'])

# Extracting year and month from the 'Date' column
tmp_train['Year'] = tmp_train['Date'].dt.year
tmp_train['Month'] = tmp_train['Date'].dt.month
tmp_train['Day'] = tmp_train['Date'].dt.day

# Grouping by year and month, and summing up the sales for each group
monthly_sales = tmp_train.groupby(['Year', 'Month'])['Sales'].sum().reset_index()

# Plotting the monthly sales trend
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales['Year'].astype(str) + '-' + monthly_sales['Month'].astype(str), monthly_sales['Sales'], marker='o')
plt.title('Monthly Sales Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)  # Rotating x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert 'Date' to datetime if it's not already
train['Date'] = pd.to_datetime(train['Date'])

# Filter for store 1 and positive sales
store1_data = train[(train['Store'] == 1)]

# Set 'Date' as index for better time series plotting
store1_data.set_index('Date', inplace=True)

# Resample to weekly frequency for smoother visualization
weekly_sales = store1_data['Sales'].resample('W').sum()

# Create the plot
plt.figure(figsize=(16, 4))
sns.lineplot(data = weekly_sales, label='Store 1 Sales')
plt.title('Store 1 Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)  # Add gridlines
plt.show()

# %% [markdown]
# # Data Split

# %%
train = train.sort_values(['Date'],ascending = False)

train['Date'] = pd.to_datetime(train['Date'])

split_date = '2015-06-01'  # adjust based on your use case

# Split the data
hold_train = train[train['Date'] < split_date].copy()
hold_test  = train[train['Date'] >= split_date].copy()

# %%
plt.figure(figsize=(12, 4))
plt.plot(train['Date'], train['Sales'], label='All Data')
plt.axvline(pd.to_datetime(split_date), color='red', linestyle='--', label='Train/Test Split')
plt.legend()
plt.title("Sales Over Time with Train/Test Split")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
# only use data of Sales > 0 and Open is 1
hold_test = hold_test[hold_test["Open"] != 0]
hold_test = hold_test[hold_test["Sales"] > 0]

hold_train = hold_train[hold_train["Open"] != 0]
hold_train = hold_train[hold_train["Sales"] > 0]

# %%
hold_test.shape
# Out:
# (58611, 18)

# %%
hold_train.shape
# Out:
# (785727, 18)

# %%
sns.histplot(data = hold_train, x='Sales')
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(data = hold_train, x='Open')
# Out:
# <Axes: xlabel='Open', ylabel='Count'>

# %%
def features_create(data):
    # Map categorical values
    mappings = {'0': 0, 'a': 1, 'b': 2, 'c': 3, 'd': 4}
    for col in ['StoreType', 'Assortment', 'StateHoliday']:
        data[col].replace(mappings, inplace=True)

    # Extract date features
    data['Date'] = pd.to_datetime(data['Date'])

    data['Year'] = data.Date.dt.year
    data['Month'] = data.Date.dt.month
    data['Day'] = data.Date.dt.day
    data['DayOfWeek'] = data.Date.dt.dayofweek
    data['WeekOfYear'] = data.Date.dt.isocalendar().week

    # Competition and promo durations
    data['CompetitionOpen'] = 12 * (data.Year - data.CompetitionOpenSinceYear.fillna(data.Year)) + \
                               (data.Month - data.CompetitionOpenSinceMonth.fillna(data.Month))
    data['PromoOpen'] = 12 * (data.Year - data.Promo2SinceYear.fillna(data.Year)) + \
                        (data.WeekOfYear - data.Promo2SinceWeek.fillna(data.WeekOfYear)) / 4.0
    data['CompetitionOpen'] = data['CompetitionOpen'].clip(lower=0)
    data['PromoOpen'] = data['PromoOpen'].clip(lower=0)

    # Promo month check
    month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun',
                 7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
    data['monthStr'] = data.Month.map(month2str)
    data.loc[data.PromoInterval == 0, 'PromoInterval'] = ''
    data['IsPromoMonth'] = 0

    for interval in data.PromoInterval.unique():
        if interval:
            for month in interval.split(','):
                data.loc[(data.monthStr == month) & (data.PromoInterval == interval), 'IsPromoMonth'] = 1

    return data

# %%
features_create(hold_train)
features_create(hold_test)
features_create(test)

print('Features creation finished')
# Out:
# Features creation finished

# %%
# drop the features of not help
hold_train.drop(['Date','Customers','Open','PromoInterval','monthStr'],axis=1,inplace =True)
hold_test.drop(['Date','Customers','Open','PromoInterval','monthStr'],axis=1,inplace =True)

# %%
# the heat map of feature-feature and feature-label correlation 
plt.subplots(figsize=(24,20))
sns.heatmap(hold_train.corr(),annot=True, vmin=-0.1, vmax=0.1,center=0)
# Out:
# <Axes: >

# %%
hold_x_train = hold_train.drop(['Sales'],axis=1 )
hold_x_test = hold_test.drop(['Sales'],axis=1 )

hold_y_train = np.log1p(hold_train.Sales)
hold_y_test = np.log1p(hold_test.Sales)

# %%
x_test = test.drop(['Id','Date','Open','PromoInterval','monthStr'],axis = 1)

# %%
def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat/y-1) ** 2))

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y,yhat)

# %%
params = {"objective": "reg:squarederror",
          "booster" : "gbtree",
          "eta": 0.03,
          "max_depth": 10,
          "subsample": 0.9,
          "colsample_bytree": 0.7,
          "verbosity": 1,
          "seed": 10
          }
num_boost_round = 6000


dtrain = xgb.DMatrix(hold_x_train, hold_y_train)
dvalid = xgb.DMatrix(hold_x_test, hold_y_test)
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
print("Train a XGBoost model")

gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, 
  early_stopping_rounds=100, feval=rmspe_xg, verbose_eval=True)


print("validating")
hold_x_test.sort_index(inplace=True) 
hold_y_test.sort_index(inplace=True) 
yhat = gbm.predict(xgb.DMatrix(hold_x_test))
error = rmspe(np.expm1(hold_y_test), np.expm1(yhat))

print('RMSPE: {:.6f}'.format(error))
# Out:
# Train a XGBoost model
# [0]	train-rmse:0.42248	train-rmspe:0.55683	eval-rmse:0.41322	eval-rmspe:0.48793
# [1]	train-rmse:0.41746	train-rmspe:0.54757	eval-rmse:0.40831	eval-rmspe:0.47918
# [2]	train-rmse:0.41210	train-rmspe:0.53785	eval-rmse:0.40312	eval-rmspe:0.47004
# [3]	train-rmse:0.40647	train-rmspe:0.52889	eval-rmse:0.39748	eval-rmspe:0.46204
# [4]	train-rmse:0.40135	train-rmspe:0.51951	eval-rmse:0.39253	eval-rmspe:0.45389
# [5]	train-rmse:0.39768	train-rmspe:0.51187	eval-rmse:0.38920	eval-rmspe:0.44705
# [6]	train-rmse:0.39431	train-rmspe:0.50575	eval-rmse:0.38602	eval-rmspe:0.44191
# [7]	train-rmse:0.39111	train-rmspe:0.50111	eval-rmse:0.38294	eval-rmspe:0.43866
# [8]	train-rmse:0.38668	train-rmspe:0.49442	eval-rmse:0.37867	eval-rmspe:0.43246
# [9]	train-rmse:0.38271	train-rmspe:0.48801	eval-rmse:0.37475	eval-rmspe:0.42652
# [10]	train-rmse:0.37808	train-rmspe:0.48048	eval-rmse:0.37020	eval-rmspe:0.41968
# [11]	train-rmse:0.37369	train-rmspe:0.47360	eval-rmse:0.36587	eval-rmspe:0.41366
# [12]	train-rmse:0.37114	train-rmspe:0.46913	eval-rmse:0.36354	eval-rmspe:0.40990
# [13]	train-rmse:0.36705	train-rmspe:0.46363	eval-rmse:0.35948	eval-rmspe:0.40440
# [14]	train-rmse:0.36320	train-rmspe:0.45841	eval-rmse:0.35567	eval-rmspe:0.39903
# [15]	train-rmse:0.35973	train-rmspe:0.45332	eval-rmse:0.35210	eval-rmspe:0.39416
# [16]	train-rmse:0.35674	train-rmspe:0.44799	eval-rmse:0.34935	eval-rmspe:0.38935
# [17]	train-rmse:0.35475	train-rmspe:0.44492	eval-rmse:0.34741	eval-rmspe:0.38700
# [18]	train-rmse:0.35225	train-rmspe:0.44070	eval-rmse:0.34531	eval-rmspe:0.38350
# [19]	train-rmse:0.34904	train-rmspe:0.43597	eval-rmse:0.34221	eval-rmspe:0.37940
# [20]	train-rmse:0.34569	train-rmspe:0.43144	eval-rmse:0.33902	eval-rmspe:0.37527
# [21]	train-rmse:0.34342	train-rmspe:0.42765	eval-rmse:0.33683	eval-rmspe:0.37202
# [22]	train-rmse:0.34132	train-rmspe:0.42428	eval-rmse:0.33496	eval-rmspe:0.36919
# [23]	train-rmse:0.33931	train-rmspe:0.42169	eval-rmse:0.33339	eval-rmspe:0.36756
# [24]	train-rmse:0.33693	train-rmspe:0.41841	eval-rmse:0.33112	eval-rmspe:0.36468
# [228]	train-rmse:0.16221	train-rmspe:0.20830	eval-rmse:0.18161	eval-rmspe:0.19891
# [229]	train-rmse:0.16191	train-rmspe:0.20805	eval-rmse:0.18135	eval-rmspe:0.19862
# [230]	train-rmse:0.16136	train-rmspe:0.20627	eval-rmse:0.18089	eval-rmspe:0.19807
# [231]	train-rmse:0.16094	train-rmspe:0.20590	eval-rmse:0.18050	eval-rmspe:0.19763
# [232]	train-rmse:0.16079	train-rmspe:0.20578	eval-rmse:0.18037	eval-rmspe:0.19749
# [233]	train-rmse:0.15990	train-rmspe:0.20493	eval-rmse:0.17958	eval-rmspe:0.19667
# [234]	train-rmse:0.15966	train-rmspe:0.20470	eval-rmse:0.17939	eval-rmspe:0.19645
# [235]	train-rmse:0.15938	train-rmspe:0.20444	eval-rmse:0.17916	eval-rmspe:0.19618
# [236]	train-rmse:0.15917	train-rmspe:0.20424	eval-rmse:0.17874	eval-rmspe:0.19578
# [237]	train-rmse:0.15889	train-rmspe:0.20397	eval-rmse:0.17851	eval-rmspe:0.19551
# [238]	train-rmse:0.15875	train-rmspe:0.20383	eval-rmse:0.17844	eval-rmspe:0.19545
# [239]	train-rmse:0.15837	train-rmspe:0.20350	eval-rmse:0.17808	eval-rmspe:0.19504
# [240]	train-rmse:0.15799	train-rmspe:0.20317	eval-rmse:0.17767	eval-rmspe:0.19458
# [241]	train-rmse:0.15746	train-rmspe:0.20261	eval-rmse:0.17720	eval-rmspe:0.19404
# [242]	train-rmse:0.15711	train-rmspe:0.20229	eval-rmse:0.17688	eval-rmspe:0.19369
# [243]	train-rmse:0.15673	train-rmspe:0.20197	eval-rmse:0.17655	eval-rmspe:0.19335
# [244]	train-rmse:0.15630	train-rmspe:0.20157	eval-rmse:0.17613	eval-rmspe:0.19289
# [245]	train-rmse:0.15593	train-rmspe:0.20056	eval-rmse:0.17580	eval-rmspe:0.19254
# [246]	train-rmse:0.15581	train-rmspe:0.20039	eval-rmse:0.17588	eval-rmspe:0.19271
# [247]	train-rmse:0.15556	train-rmspe:0.20017	eval-rmse:0.17568	eval-rmspe:0.19249
# [248]	train-rmse:0.15545	train-rmspe:0.20008	eval-rmse:0.17558	eval-rmspe:0.19240
# [249]	train-rmse:0.15527	train-rmspe:0.19978	eval-rmse:0.17545	eval-rmspe:0.19227
# [250]	train-rmse:0.15492	train-rmspe:0.19834	eval-rmse:0.17518	eval-rmspe:0.19195
# [251]	train-rmse:0.15483	train-rmspe:0.19824	eval-rmse:0.17509	eval-rmspe:0.19184
# [252]	train-rmse:0.15434	train-rmspe:0.19781	eval-rmse:0.17464	eval-rmspe:0.19135
# [253]	train-rmse:0.15393	train-rmspe:0.19744	eval-rmse:0.17427	eval-rmspe:0.19093
# [254]	train-rmse:0.15360	train-rmspe:0.19669	eval-rmse:0.17400	eval-rmspe:0.19064
# [255]	train-rmse:0.15310	train-rmspe:0.19624	eval-rmse:0.17357	eval-rmspe:0.19017
# [256]	train-rmse:0.15268	train-rmspe:0.19587	eval-rmse:0.17316	eval-rmspe:0.18974
# [315]	train-rmse:0.13678	train-rmspe:0.16758	eval-rmse:0.16029	eval-rmspe:0.17600
# [316]	train-rmse:0.13670	train-rmspe:0.16748	eval-rmse:0.16028	eval-rmspe:0.17599
# [317]	train-rmse:0.13643	train-rmspe:0.16723	eval-rmse:0.15996	eval-rmspe:0.17562
# [318]	train-rmse:0.13634	train-rmspe:0.16714	eval-rmse:0.15999	eval-rmspe:0.17569
# [319]	train-rmse:0.13626	train-rmspe:0.16704	eval-rmse:0.15997	eval-rmspe:0.17569
# [320]	train-rmse:0.13563	train-rmspe:0.16652	eval-rmse:0.15945	eval-rmspe:0.17514
# [321]	train-rmse:0.13543	train-rmspe:0.16634	eval-rmse:0.15928	eval-rmspe:0.17496
# [322]	train-rmse:0.13518	train-rmspe:0.16611	eval-rmse:0.15907	eval-rmspe:0.17471
# [323]	train-rmse:0.13498	train-rmspe:0.16591	eval-rmse:0.15862	eval-rmspe:0.17422
# [324]	train-rmse:0.13459	train-rmspe:0.16557	eval-rmse:0.15829	eval-rmspe:0.17384
# [325]	train-rmse:0.13442	train-rmspe:0.16541	eval-rmse:0.15814	eval-rmspe:0.17368
# [326]	train-rmse:0.13425	train-rmspe:0.16525	eval-rmse:0.15800	eval-rmspe:0.17354
# [327]	train-rmse:0.13391	train-rmspe:0.16492	eval-rmse:0.15771	eval-rmspe:0.17320
# [328]	train-rmse:0.13377	train-rmspe:0.16387	eval-rmse:0.15759	eval-rmspe:0.17307
# [329]	train-rmse:0.13365	train-rmspe:0.16330	eval-rmse:0.15752	eval-rmspe:0.17300
# [330]	train-rmse:0.13359	train-rmspe:0.16324	eval-rmse:0.15750	eval-rmspe:0.17301
# [331]	train-rmse:0.13317	train-rmspe:0.16284	eval-rmse:0.15714	eval-rmspe:0.17260
# [332]	train-rmse:0.13291	train-rmspe:0.16178	eval-rmse:0.15695	eval-rmspe:0.17238
# [333]	train-rmse:0.13266	train-rmspe:0.16154	eval-rmse:0.15673	eval-rmspe:0.17215
# [334]	train-rmse:0.13244	train-rmspe:0.16130	eval-rmse:0.15657	eval-rmspe:0.17198
# [335]	train-rmse:0.13229	train-rmspe:0.16104	eval-rmse:0.15646	eval-rmspe:0.17185
# [336]	train-rmse:0.13215	train-rmspe:0.16092	eval-rmse:0.15634	eval-rmspe:0.17175
# [337]	train-rmse:0.13181	train-rmspe:0.16059	eval-rmse:0.15606	eval-rmspe:0.17142
# [338]	train-rmse:0.13164	train-rmspe:0.15979	eval-rmse:0.15593	eval-rmspe:0.17127
# [339]	train-rmse:0.13146	train-rmspe:0.15913	eval-rmse:0.15581	eval-rmspe:0.17113
# [340]	train-rmse:0.13132	train-rmspe:0.15896	eval-rmse:0.15571	eval-rmspe:0.17101
# [341]	train-rmse:0.13114	train-rmspe:0.15821	eval-rmse:0.15559	eval-rmspe:0.17088
# [342]	train-rmse:0.13098	train-rmspe:0.15806	eval-rmse:0.15545	eval-rmspe:0.17072
# [343]	train-rmse:0.13087	train-rmspe:0.15750	eval-rmse:0.15537	eval-rmspe:0.17062
# [344]	train-rmse:0.13056	train-rmspe:0.15721	eval-rmse:0.15513	eval-rmspe:0.17037
# [345]	train-rmse:0.13026	train-rmspe:0.15690	eval-rmse:0.15492	eval-rmspe:0.17014
# [346]	train-rmse:0.13012	train-rmspe:0.15677	eval-rmse:0.15481	eval-rmspe:0.17002
# [347]	train-rmse:0.12997	train-rmspe:0.15663	eval-rmse:0.15468	eval-rmspe:0.16987
# [348]	train-rmse:0.12987	train-rmspe:0.15651	eval-rmse:0.15460	eval-rmspe:0.16978
# [349]	train-rmse:0.12979	train-rmspe:0.15643	eval-rmse:0.15455	eval-rmspe:0.16973
# [350]	train-rmse:0.12968	train-rmspe:0.15580	eval-rmse:0.15447	eval-rmspe:0.16965
# [351]	train-rmse:0.12958	train-rmspe:0.15570	eval-rmse:0.15440	eval-rmspe:0.16960
# [352]	train-rmse:0.12943	train-rmspe:0.15557	eval-rmse:0.15428	eval-rmspe:0.16946
# [353]	train-rmse:0.12919	train-rmspe:0.15532	eval-rmse:0.15413	eval-rmspe:0.16931
# [354]	train-rmse:0.12913	train-rmspe:0.15526	eval-rmse:0.15409	eval-rmspe:0.16927
# [355]	train-rmse:0.12887	train-rmspe:0.15501	eval-rmse:0.15389	eval-rmspe:0.16903
# [356]	train-rmse:0.12867	train-rmspe:0.15475	eval-rmse:0.15372	eval-rmspe:0.16883
# [357]	train-rmse:0.12852	train-rmspe:0.15461	eval-rmse:0.15360	eval-rmspe:0.16870
# [358]	train-rmse:0.12830	train-rmspe:0.15440	eval-rmse:0.15337	eval-rmspe:0.16843
# [359]	train-rmse:0.12820	train-rmspe:0.15430	eval-rmse:0.15329	eval-rmspe:0.16832
# [360]	train-rmse:0.12803	train-rmspe:0.15415	eval-rmse:0.15314	eval-rmspe:0.16816
# [361]	train-rmse:0.12769	train-rmspe:0.15381	eval-rmse:0.15289	eval-rmspe:0.16786
# [362]	train-rmse:0.12744	train-rmspe:0.15355	eval-rmse:0.15271	eval-rmspe:0.16765
# [363]	train-rmse:0.12726	train-rmspe:0.15338	eval-rmse:0.15251	eval-rmspe:0.16741
# [364]	train-rmse:0.12700	train-rmspe:0.15308	eval-rmse:0.15232	eval-rmspe:0.16722
# [365]	train-rmse:0.12675	train-rmspe:0.15283	eval-rmse:0.15204	eval-rmspe:0.16691
# [366]	train-rmse:0.12669	train-rmspe:0.15275	eval-rmse:0.15203	eval-rmspe:0.16692
# [367]	train-rmse:0.12644	train-rmspe:0.15252	eval-rmse:0.15181	eval-rmspe:0.16668
# [368]	train-rmse:0.12624	train-rmspe:0.15235	eval-rmse:0.15168	eval-rmspe:0.16654
# [369]	train-rmse:0.12604	train-rmspe:0.15216	eval-rmse:0.15153	eval-rmspe:0.16638
# [370]	train-rmse:0.12596	train-rmspe:0.15207	eval-rmse:0.15149	eval-rmspe:0.16635
# [371]	train-rmse:0.12584	train-rmspe:0.15196	eval-rmse:0.15139	eval-rmspe:0.16624
# [372]	train-rmse:0.12563	train-rmspe:0.15167	eval-rmse:0.15122	eval-rmspe:0.16603
# [490]	train-rmse:0.10990	train-rmspe:0.13073	eval-rmse:0.14030	eval-rmspe:0.15389
# [491]	train-rmse:0.10981	train-rmspe:0.13064	eval-rmse:0.14023	eval-rmspe:0.15382
# [492]	train-rmse:0.10976	train-rmspe:0.13058	eval-rmse:0.14017	eval-rmspe:0.15376
# [493]	train-rmse:0.10971	train-rmspe:0.13054	eval-rmse:0.14020	eval-rmspe:0.15380
# [494]	train-rmse:0.10961	train-rmspe:0.13043	eval-rmse:0.14014	eval-rmspe:0.15371
# [495]	train-rmse:0.10956	train-rmspe:0.13039	eval-rmse:0.14009	eval-rmspe:0.15363
# [496]	train-rmse:0.10950	train-rmspe:0.13000	eval-rmse:0.14004	eval-rmspe:0.15358
# [497]	train-rmse:0.10936	train-rmspe:0.12987	eval-rmse:0.13994	eval-rmspe:0.15346
# [498]	train-rmse:0.10922	train-rmspe:0.12972	eval-rmse:0.13983	eval-rmspe:0.15333
# [499]	train-rmse:0.10902	train-rmspe:0.12953	eval-rmse:0.13970	eval-rmspe:0.15318
# [500]	train-rmse:0.10895	train-rmspe:0.12945	eval-rmse:0.13969	eval-rmspe:0.15318
# [501]	train-rmse:0.10887	train-rmspe:0.12937	eval-rmse:0.13963	eval-rmspe:0.15311
# [502]	train-rmse:0.10871	train-rmspe:0.12920	eval-rmse:0.13951	eval-rmspe:0.15297
# [503]	train-rmse:0.10858	train-rmspe:0.12907	eval-rmse:0.13941	eval-rmspe:0.15287
# [504]	train-rmse:0.10849	train-rmspe:0.12898	eval-rmse:0.13932	eval-rmspe:0.15278
# [505]	train-rmse:0.10839	train-rmspe:0.12888	eval-rmse:0.13926	eval-rmspe:0.15272
# [506]	train-rmse:0.10832	train-rmspe:0.12881	eval-rmse:0.13929	eval-rmspe:0.15276
# [507]	train-rmse:0.10827	train-rmspe:0.12875	eval-rmse:0.13925	eval-rmspe:0.15271
# [508]	train-rmse:0.10817	train-rmspe:0.12866	eval-rmse:0.13918	eval-rmspe:0.15263
# [509]	train-rmse:0.10801	train-rmspe:0.12851	eval-rmse:0.13907	eval-rmspe:0.15251
# [510]	train-rmse:0.10792	train-rmspe:0.12843	eval-rmse:0.13899	eval-rmspe:0.15242
# [511]	train-rmse:0.10785	train-rmspe:0.12835	eval-rmse:0.13895	eval-rmspe:0.15238
# [512]	train-rmse:0.10780	train-rmspe:0.12830	eval-rmse:0.13893	eval-rmspe:0.15236
# [513]	train-rmse:0.10776	train-rmspe:0.12824	eval-rmse:0.13894	eval-rmspe:0.15239
# [514]	train-rmse:0.10767	train-rmspe:0.12814	eval-rmse:0.13888	eval-rmspe:0.15232
# [515]	train-rmse:0.10755	train-rmspe:0.12802	eval-rmse:0.13878	eval-rmspe:0.15221
# [516]	train-rmse:0.10745	train-rmspe:0.12792	eval-rmse:0.13870	eval-rmspe:0.15212
# [517]	train-rmse:0.10729	train-rmspe:0.12774	eval-rmse:0.13859	eval-rmspe:0.15199
# [518]	train-rmse:0.10724	train-rmspe:0.12770	eval-rmse:0.13856	eval-rmspe:0.15197
# [519]	train-rmse:0.10716	train-rmspe:0.12722	eval-rmse:0.13852	eval-rmspe:0.15193
# [520]	train-rmse:0.10709	train-rmspe:0.12706	eval-rmse:0.13859	eval-rmspe:0.15202
# [521]	train-rmse:0.10701	train-rmspe:0.12698	eval-rmse:0.13853	eval-rmspe:0.15196
# [522]	train-rmse:0.10692	train-rmspe:0.12687	eval-rmse:0.13846	eval-rmspe:0.15189
# [523]	train-rmse:0.10681	train-rmspe:0.12676	eval-rmse:0.13839	eval-rmspe:0.15182
# [524]	train-rmse:0.10677	train-rmspe:0.12671	eval-rmse:0.13839	eval-rmspe:0.15183
# [525]	train-rmse:0.10670	train-rmspe:0.12664	eval-rmse:0.13833	eval-rmspe:0.15177
# [526]	train-rmse:0.10663	train-rmspe:0.12657	eval-rmse:0.13829	eval-rmspe:0.15173
# [527]	train-rmse:0.10660	train-rmspe:0.12654	eval-rmse:0.13825	eval-rmspe:0.15169
# [528]	train-rmse:0.10654	train-rmspe:0.12649	eval-rmse:0.13823	eval-rmspe:0.15167
# [529]	train-rmse:0.10646	train-rmspe:0.12641	eval-rmse:0.13817	eval-rmspe:0.15160
# [530]	train-rmse:0.10637	train-rmspe:0.12596	eval-rmse:0.13820	eval-rmspe:0.15166
# [531]	train-rmse:0.10622	train-rmspe:0.12578	eval-rmse:0.13808	eval-rmspe:0.15151
# [532]	train-rmse:0.10617	train-rmspe:0.12568	eval-rmse:0.13807	eval-rmspe:0.15152
# [533]	train-rmse:0.10614	train-rmspe:0.12564	eval-rmse:0.13800	eval-rmspe:0.15144
# [534]	train-rmse:0.10599	train-rmspe:0.12546	eval-rmse:0.13789	eval-rmspe:0.15133
# [535]	train-rmse:0.10595	train-rmspe:0.12541	eval-rmse:0.13785	eval-rmspe:0.15128
# [536]	train-rmse:0.10587	train-rmspe:0.12532	eval-rmse:0.13797	eval-rmspe:0.15144
# [537]	train-rmse:0.10575	train-rmspe:0.12520	eval-rmse:0.13789	eval-rmspe:0.15135
# [538]	train-rmse:0.10568	train-rmspe:0.12511	eval-rmse:0.13784	eval-rmspe:0.15129
# [539]	train-rmse:0.10559	train-rmspe:0.12502	eval-rmse:0.13777	eval-rmspe:0.15120
# [540]	train-rmse:0.10551	train-rmspe:0.12494	eval-rmse:0.13770	eval-rmspe:0.15113
# [541]	train-rmse:0.10544	train-rmspe:0.12487	eval-rmse:0.13767	eval-rmspe:0.15110
# [542]	train-rmse:0.10535	train-rmspe:0.12477	eval-rmse:0.13760	eval-rmspe:0.15102
# [543]	train-rmse:0.10531	train-rmspe:0.12472	eval-rmse:0.13759	eval-rmspe:0.15102
# [544]	train-rmse:0.10521	train-rmspe:0.12461	eval-rmse:0.13752	eval-rmspe:0.15094
# [545]	train-rmse:0.10516	train-rmspe:0.12456	eval-rmse:0.13749	eval-rmspe:0.15092
# [546]	train-rmse:0.10509	train-rmspe:0.12450	eval-rmse:0.13744	eval-rmspe:0.15085
# [547]	train-rmse:0.10501	train-rmspe:0.12442	eval-rmse:0.13733	eval-rmspe:0.15072
# [548]	train-rmse:0.10495	train-rmspe:0.12435	eval-rmse:0.13722	eval-rmspe:0.15061
# [549]	train-rmse:0.10486	train-rmspe:0.12427	eval-rmse:0.13717	eval-rmspe:0.15055
# [550]	train-rmse:0.10481	train-rmspe:0.12421	eval-rmse:0.13714	eval-rmspe:0.15052
# [551]	train-rmse:0.10474	train-rmspe:0.12414	eval-rmse:0.13712	eval-rmspe:0.15051
# [552]	train-rmse:0.10469	train-rmspe:0.12405	eval-rmse:0.13709	eval-rmspe:0.15048
# [553]	train-rmse:0.10463	train-rmspe:0.12399	eval-rmse:0.13703	eval-rmspe:0.15043
# [554]	train-rmse:0.10457	train-rmspe:0.12360	eval-rmse:0.13705	eval-rmspe:0.15045
# [555]	train-rmse:0.10444	train-rmspe:0.12347	eval-rmse:0.13693	eval-rmspe:0.15032
# [556]	train-rmse:0.10438	train-rmspe:0.12341	eval-rmse:0.13690	eval-rmspe:0.15028
# [557]	train-rmse:0.10434	train-rmspe:0.12336	eval-rmse:0.13687	eval-rmspe:0.15027
# [558]	train-rmse:0.10428	train-rmspe:0.12330	eval-rmse:0.13684	eval-rmspe:0.15023
# [559]	train-rmse:0.10418	train-rmspe:0.12321	eval-rmse:0.13678	eval-rmspe:0.15015
# [560]	train-rmse:0.10415	train-rmspe:0.12318	eval-rmse:0.13677	eval-rmspe:0.15015
# [561]	train-rmse:0.10407	train-rmspe:0.12305	eval-rmse:0.13672	eval-rmspe:0.15007
# [562]	train-rmse:0.10394	train-rmspe:0.12293	eval-rmse:0.13664	eval-rmspe:0.14998
# [563]	train-rmse:0.10391	train-rmspe:0.12284	eval-rmse:0.13662	eval-rmspe:0.14995
# [564]	train-rmse:0.10378	train-rmspe:0.12273	eval-rmse:0.13652	eval-rmspe:0.14984
# [565]	train-rmse:0.10367	train-rmspe:0.12259	eval-rmse:0.13643	eval-rmspe:0.14974
# [566]	train-rmse:0.10363	train-rmspe:0.12256	eval-rmse:0.13641	eval-rmspe:0.14971
# [567]	train-rmse:0.10358	train-rmspe:0.12250	eval-rmse:0.13647	eval-rmspe:0.14982
# [568]	train-rmse:0.10352	train-rmspe:0.12244	eval-rmse:0.13644	eval-rmspe:0.14979
# [569]	train-rmse:0.10337	train-rmspe:0.12229	eval-rmse:0.13632	eval-rmspe:0.14966
# [570]	train-rmse:0.10330	train-rmspe:0.12222	eval-rmse:0.13628	eval-rmspe:0.14961
# [571]	train-rmse:0.10318	train-rmspe:0.12209	eval-rmse:0.13619	eval-rmspe:0.14951
# [572]	train-rmse:0.10311	train-rmspe:0.12171	eval-rmse:0.13615	eval-rmspe:0.14947
# [573]	train-rmse:0.10306	train-rmspe:0.12166	eval-rmse:0.13614	eval-rmspe:0.14945
# [574]	train-rmse:0.10295	train-rmspe:0.12154	eval-rmse:0.13606	eval-rmspe:0.14936
# [575]	train-rmse:0.10292	train-rmspe:0.12152	eval-rmse:0.13604	eval-rmspe:0.14933
# [576]	train-rmse:0.10286	train-rmspe:0.12117	eval-rmse:0.13601	eval-rmspe:0.14929
# [1906]	train-rmse:0.07377	train-rmspe:0.08054	eval-rmse:0.12836	eval-rmspe:0.14188
# [1907]	train-rmse:0.07376	train-rmspe:0.08053	eval-rmse:0.12836	eval-rmspe:0.14189
# validating
# RMSPE: 0.141886

# %%
# analysis by hold set
res = pd.DataFrame(data = hold_y_test)
res['Prediction'] = yhat
res = pd.merge(hold_x_test, res, left_index= True, right_index=True)
res['Ratio'] = res.Prediction / res.Sales
res['Error'] = abs(res.Ratio-1)
res['Weight'] = res.Sales / res.Prediction
res.head()
# Out:
#    Store  DayOfWeek  Promo  StateHoliday  SchoolHoliday  StoreType  \
# 0      1          4      1             0              1          3
# 1      2          4      1             0              1          1
# 2      3          4      1             0              1          1
# 3      4          4      1             0              1          3
# 4      5          4      1             0              1          1
#
#    Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0           1               1270.0                        9.0
# 1           1                570.0                       11.0
# 2           1              14130.0                       12.0
# 3           3                620.0                        9.0
# 4           1              29910.0                        4.0
#
#    CompetitionOpenSinceYear  ...  Day  WeekOfYear  CompetitionOpen  PromoOpen  \
# 0                    2008.0  ...   31          31             82.0   24187.75
# 1                    2007.0  ...   31          31             92.0       64.5
# 2                    2006.0  ...   31          31            103.0      52.25
# 3                    2009.0  ...   31          31             70.0   24187.75
# 4                    2015.0  ...   31          31              3.0   24187.75
#
#    IsPromoMonth     Sales  Prediction     Ratio     Error    Weight
# 0             0  8.568646    8.560955  0.999102  0.000898  1.000898
# 1             1  8.710290    8.688002  0.997441  0.002559  1.002565
# 2             1  9.025816    9.056685  1.003420  0.003420  0.996592
# 3             0  9.546527    9.373196  0.981844  0.018156  1.018492
# 4             0  8.481151    8.765378  1.033513  0.033513  0.967574
#
# [5 rows x 25 columns]

# %%
col_1 = ['Sales','Prediction']
col_2 = ['Ratio']
L=np.random.randint(low=1, high = 1115, size = 3) 
print('Mean Ratio of predition and real sales data is {}: store all'.format(res.Ratio.mean()))
for i in L:
    
    s1 = pd.DataFrame(res[res['Store']==i], columns = col_1)
    s2 = pd.DataFrame(res[res['Store']==i], columns = col_2)
    s1.plot(title = 'Comparation of predition and real sales data: store {}'.format(i),figsize=(12,4))
    s2.plot(title = 'Ratio of predition and real sales data: store {}'.format(i),figsize=(12,4))
    print('Mean Ratio of predition and real sales data is {}: store {}'.format(s2.Ratio.mean(),i))
# Out:
# Mean Ratio of predition and real sales data is 1.0044771633934804: store all
# Mean Ratio of predition and real sales data is 1.0055788266862957: store 484
# Mean Ratio of predition and real sales data is 1.0096128819709251: store 812
# Mean Ratio of predition and real sales data is 1.0042135539178076: store 672

# %%
# the worst 10 samples
res.sort_values(['Error'],ascending=False,inplace= True)
res[:10]
# Out:
#        Store  DayOfWeek  Promo  StateHoliday  SchoolHoliday  StoreType  \
# 23706    292          4      0             0              0          1
# 63969    415          3      1             1              0          4
# 39806    782          4      0             0              0          3
# 34358    909          2      1             0              0          1
# 65084    415          2      1             0              0          4
# 62854    415          4      1             0              0          4
# 44393    909          0      0             0              0          1
# 61739    415          5      0             0              0          4
# 67816    917          0      1             0              0          1
# 30396    292          5      0             0              0          1
#
#        Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 23706           1               1100.0                        6.0
# 63969           3               6910.0                        4.0
# 39806           3               5390.0                        8.0
# 34358           3               1680.0                        0.0
# 65084           3               6910.0                        4.0
# 62854           3               6910.0                        4.0
# 44393           3               1680.0                        0.0
# 61739           3               6910.0                        4.0
# 67816           1               7240.0                        2.0
# 30396           1               1100.0                        6.0
#
#        CompetitionOpenSinceYear  ...  Day  WeekOfYear  CompetitionOpen  \
# 23706                    2009.0  ...   10          28             73.0
# 63969                    2005.0  ...    4          23            122.0
# 39806                    2003.0  ...   26          26            142.0
# 34358                       0.0  ...    1          27          24187.0
# 65084                    2005.0  ...    3          23            122.0
# 62854                    2005.0  ...    5          23            122.0
# 44393                       0.0  ...   22          26          24186.0
# 61739                    2005.0  ...    6          23            122.0
# 67816                    2010.0  ...    1          23             64.0
# 30396                    2009.0  ...    4          27             73.0
#
#        PromoOpen  IsPromoMonth      Sales  Prediction     Ratio     Error  \
# 23706    24187.0             0   6.920672    8.615812  1.244939  0.244939
# 63969   24185.75             0   7.289611    8.802694  1.207567  0.207567
# 39806      42.25             0   7.260523    8.606154  1.185335  0.185335
# 34358       67.5             0   8.174139    9.543529  1.167527  0.167527
# 65084   24185.75             0   7.713785    8.932693  1.158017  0.158017
# 62854   24185.75             0   7.794823    8.899099  1.141668  0.141668
# 44393      67.25             0  10.634701    9.141666  0.859607  0.140393
# 61739   24185.75             0   7.779049    8.857574  1.138645  0.138645
# 67816   24185.75             0   8.206856    9.267625  1.129254  0.129254
# 30396   24186.75             0   7.406711    8.362123  1.128993  0.128993
#
#          Weight
# 23706  0.803252
# 63969  0.828111
# 39806  0.843643
# 34358  0.856511
# 65084  0.863545
# 62854  0.875911
# 44393  1.163322
# 61739  0.878237
# 67816  0.885540
# 30396  0.885745
#
# [10 rows x 25 columns]

# %%
# whole correction
print("weight correction")
W=[(0.990+(i/1000)) for i in range(20)]
S =[]
for w in W:
    error = rmspe(np.expm1(hold_y_test), np.expm1(yhat*w))
    print('RMSPE for {:.3f}:{:.6f}'.format(w,error))
    S.append(error)
Score = pd.Series(S,index=W)
Score.plot()
BS = Score[Score.values == Score.values.min()]
print ('Best weight for Score:{}'.format(BS))
# Out:
# weight correction
# RMSPE for 0.990:0.131077
# RMSPE for 0.991:0.129531
# RMSPE for 0.992:0.128528
# RMSPE for 0.993:0.128098
# RMSPE for 0.994:0.128260
# RMSPE for 0.995:0.129030
# RMSPE for 0.996:0.130411
# RMSPE for 0.997:0.132401
# RMSPE for 0.998:0.134990
# RMSPE for 0.999:0.138159
# RMSPE for 1.000:0.141886
# RMSPE for 1.001:0.146144
# RMSPE for 1.002:0.150903
# RMSPE for 1.003:0.156134
# RMSPE for 1.004:0.161804
# RMSPE for 1.005:0.167886
# RMSPE for 1.006:0.174351
# RMSPE for 1.007:0.181171
# RMSPE for 1.008:0.188323
# RMSPE for 1.009:0.195784
# Best weight for Score:0.993    0.128098
# dtype: float64

# %%
# correction by store
L = range(1115)
W_ho = []
W_test = []
for i in L:
    s1 = pd.DataFrame(res[res['Store'] == i+1], columns = col_1)
    s2 = pd.DataFrame(x_test[x_test['Store'] == i+1])
    W1=[ (0.990 + (i /1000)) for i in range(20)]
    S =[]
    for w in W1:
        error = rmspe(np.expm1(s1.Sales), np.expm1(s1.Prediction * w))
        S.append(error)
    Score = pd.Series(S, index = W1)
    BS = Score[Score.values == Score.values.min()]
    a = np.array(BS.index.values)
    b_ho = a.repeat(len(s1))
    b_test = a.repeat(len(s2))
    W_ho.extend(b_ho.tolist())
    W_test.extend(b_test.tolist())

# %%
yhat_new = yhat*W_ho
error = rmspe(np.expm1(hold_y_test), np.expm1(yhat_new))
print ('RMSPE for weight corretion {:6f}'.format(error))
# Out:
# RMSPE for weight corretion 0.132121

# %%
print("Make predictions on the test set")
dtest = xgb.DMatrix(x_test)
test_predections = gbm.predict(dtest)

result = pd.DataFrame({"Id": test['Id'], 'Sales': np.expm1(test_predections)})
result.to_csv("Rossmann_submission_1.csv", index=False)

result = pd.DataFrame({"Id": test['Id'], 'Sales': np.expm1(test_predections * 0.995)})
result.to_csv("Rossmann_submission_2.csv", index=False)

result = pd.DataFrame({"Id": test['Id'], 'Sales': np.expm1(test_predections * W_test)})
result.to_csv("Rossmann_submission_3.csv", index=False)
# Out:
# Make predictions on the test set
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 print("Make predictions on the test set")
#       2 dtest = xgb.DMatrix(x_test)
# ----> 3 test_predections = gbm.predict(dtest)
#       5 result = pd.DataFrame({"Id": test['Id'], 'Sales': np.expm1(test_predections)})
#       6 result.to_csv("Rossmann_submission_1.csv", index=False)
#
# File c:\Users\Legion\anaconda3\envs\Data_science\Lib\site-packages\xgboost\core.py:2359, in Booster.predict(self, data, output_margin, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training, iteration_range, strict_shape)
#    2357 if validate_features:
#    2358     fn = data.feature_names
# -> 2359     self._validate_features(fn)
#    2360 args = {
#    2361     "type": 0,
#    2362     "training": training,
#    (...)
#    2365     "strict_shape": strict_shape,
#    2366 }
#    2368 def assign_type(t: int) -> None:
#
# File c:\Users\Legion\anaconda3\envs\Data_science\Lib\site-packages\xgboost\core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['Store', 'DayOfWeek', 'Promo', 'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'Year', 'Month', 'Day', 'WeekOfYear', 'CompetitionOpen', 'PromoOpen', 'IsPromoMonth'] ['Store', 'DayOfWeek', 'Promo', 'StateHoliday', 'SchoolHoliday', 'Month', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'Year', 'Day', 'WeekOfYear', 'CompetitionOpen', 'PromoOpen', 'IsPromoMonth']

# %%
hold_y_test
# Out:
# (58611,)

# %%
# feature importance
xgb.plot_importance(gbm)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>
